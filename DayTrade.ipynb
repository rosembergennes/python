# %% [markdown]
# <a href="https://colab.research.google.com/github/rosembergennes/python/blob/master/DayTrade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Preparação do Ambiente

# %%
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# !pip install dnspython

import time
from datetime import datetime, timedelta
from selenium import webdriver
import requests
import pandas as pd
from google.colab import files
import os
import numpy as np
from pandas import DataFrame
import pandas as pd
from datetime import timedelta, date ,datetime
from decimal import Decimal
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import datetime
from pymongo import MongoClient
import pprint
import datetime
import json

# %%
# Restart Rum time para entender o dnspython aula 13/04/2020 11minutos e 18segundos

# %%
# obtendo dados do atlas mongodb
client = MongoClient("mXXXXXXXXXXXXXXXXXXXXX")
db = client.acoes
collection = db.bolsabrasil
data = pd.DataFrame(list(collection.find()))

# %%
# data.info()
data.head()
# Out:
#                         _id     DATPRG  CODBDI  ... CRESULT5    VPA GIROATIVO
# 0  5f2be5e43427840390ba032a 2020-08-05       2  ...      0.9  10.68      0.40
# 1  5f2be5e43427840390ba032b 2020-08-05       2  ...    -17.7  18.53      0.00
# 2  5f2be5e43427840390ba032c 2020-08-05       2  ...      3.0   4.70      0.43
# 3  5f2be5e43427840390ba032d 2020-08-05       2  ...     43.5  -1.21      0.14
# 4  5f2be5e43427840390ba032e 2020-08-05       2  ...     10.7   3.57      0.16
#
# [5 rows x 27 columns]
